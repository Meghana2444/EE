# %% [markdown]
# <a href="https://colab.research.google.com/github/Meghana2444/EE/blob/main/2305a21l14w8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

marks=np.array([[101,35,98,43,65,78,96], [102,87,45,98,65,34,78], [103,45,26,78,45,67,34], [104,45, 56, 67, 78,89,90], [105,23,34,45,56,76,87]])
students=marks.shape[0]

Hall_Ticket_No=int(input("enter hall ticket no."))

for i in range(students ):
   if (Hall_Ticket_No==marks[i,0]):
    break
index=i

marks_percentage=np.sum(marks [index,1:marks.shape[1]])*100/600

count=0

failed_sub=[]
for i in range(1, marks.shape[1]):
  if (marks [index, i]<35):
    count=count+1
    failed_sub.append(i)
print("================================")

print("   Results Status                ")

print("=================================")
if(count>0):
  print("Fail")
  print("Failed Subjects:",)
  for i in range(len(failed_sub)):
    if(failed_sub[i]==1):
      print("Telugu")
    if(failed_sub[i]==2):
      print("English")
    if(failed_sub[i]==3):
      print("Hindi")
    if(failed_sub[i]==4):
      print("Maths")
    if(failed_sub[i]==5):
      print("Science")
    if(failed_sub[i]==6):
      print("Social")
else:
  print("Pass")
  print("Percentage of marks:",np.round(marks_percentage))
  print("==============================")
  print("       Tsms      ")
  print("       Score Board             ")
  print("===============================")
  print("Roll No:", Hall_Ticket_No)
  print("Telugu:", marks [index, 1])
  print("English:", marks [index, 2])
  print("Hindi:", marks [index, 3])
  print("Maths:", marks [index, 4])
  print("Science:", marks [index, 5])
  print("social:", marks [index, 6])
# Out:
# enter hall ticket no.14
# ================================
#    Results Status
# =================================
# Fail
# Failed Subjects:
# Telugu
# English
